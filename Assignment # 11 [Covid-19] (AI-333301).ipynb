# %% [markdown]
# Tasks for Data Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Load and Display Data → Read the dataset and print the first 5 rows.

# %%
Data = pd.read_csv('covid_19_country_wise_latest.csv')

Data.head()
# Out:
#    Unnamed: 0 Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# 0           0    Afghanistan      36263   1269      25198    9796      106.0
# 1           1        Albania       4880    144       2745    1991      117.0
# 2           2        Algeria      27973   1163      18837    7973      616.0
# 3           3        Andorra        907     52        803      52       10.0
# 4           4         Angola        950     41        242     667       18.0
#
#    New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0        10.0             18                3.50                  69.49
# 1         6.0             63                2.95                  56.25
# 2         8.0            749                4.16                  67.34
# 3         0.0              0                5.73                  88.53
# 4         1.0              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# ...

# %% [markdown]
# 2. Set the Dataset index is Unnamed: 0

# %%
Data = pd.read_csv('covid_19_country_wise_latest.csv', index_col=0)
Data.head()
# Out:
#   Country/Region  Confirmed Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263   1269      25198    9796      106.0        10.0
# 1        Albania       4880    144       2745    1991      117.0         6.0
# 2        Algeria      27973   1163      18837    7973      616.0         8.0
# 3        Andorra        907     52        803      52       10.0         0.0
# 4         Angola        950     41        242     667       18.0         1.0
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %% [markdown]
# 3. Now replace the index column Unnamed: 0 name with index

# %%
Data.index.name = 'index'

Data.head()
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New cases  \
# index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths / 100 Recovered  Confirmed last week  1 week change  \
# index
# ...

# %% [markdown]
# 4. Create Function that take dataset columns and replace whitespace
# with Underscore and update dataset automatically and the pass the
# dataset.

# %%
def replace_whitespace_with_underscore(df):
    
    original_columns = list(df.columns)

    new_columns = {col: col.replace(" ", "_") for col in original_columns}

    df.rename(columns=new_columns, inplace=True)  

    return df

Data = pd.read_csv('covid_19_country_wise_latest.csv', index_col=0)
Data.index.name = 'index'

Data = replace_whitespace_with_underscore(Data)

Data.tail()
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 182    West Bank and Gaza      10621     78       3752    6791      152.0
# 183        Western Sahara         10      1          8       1        0.0
# 184                 Yemen       1691    483        833     375       10.0
# 185                Zambia       4552    140       2815    1597       71.0
# 186              Zimbabwe       2704    non        542    2126      192.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 182           2.0              0                0.73                  35.33
# 183           0.0              0               10.00                  80.00
# 184           4.0             36               28.56                  49.26
# 185           1.0            465                3.08                  61.84
# 186           2.0             24                1.33                  20.04
#
# ...

# %% [markdown]
# 5. Check Basic Information → Find column names, data types, and
# missing values.

# %%
column_names = Data.columns

data_types = Data.dtypes

missing_values = Data.isnull().sum()

print("Column Names:\n", column_names)
print("\nData Types:\n", data_types)
print("\nMissing Values:\n", missing_values)
# Out:
# Column Names:
#  Index(['Country/Region', 'Confirmed', 'Deaths', 'Recovered', 'Active',
#        'New_cases', 'New_deaths', 'New_recovered', 'Deaths_/_100_Cases',
#        'Recovered_/_100_Cases', 'Deaths_/_100_Recovered',
#        'Confirmed_last_week', '1_week_change', '1_week_%_increase',
#        'WHO_Region'],
#       dtype='object')
#
# Data Types:
#  Country/Region             object
# Confirmed                   int64
# Deaths                     object
# Recovered                   int64
# Active                      int64
# New_cases                 float64
# New_deaths                float64
# New_recovered               int64
# Deaths_/_100_Cases        float64
# Recovered_/_100_Cases     float64
# Deaths_/_100_Recovered    float64
# Confirmed_last_week         int64
# 1_week_change               int64
# 1_week_%_increase         float64
# WHO_Region                 object
# dtype: object
#
# Missing Values:
#  Country/Region             0
# Confirmed                  0
# ...

# %% [markdown]
# 6. fill the nan values with the mean of the column

# %%
for column in Data.columns:
    if Data[column].isnull().any():  
        mean_value = Data[column].mean()  
        Data[column].fillna(mean_value, inplace=True) 


Data.head()
# Out:
#       Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %% [markdown]
# 7. Count the number of unique countries in the dataset.

# %%
num_unique_countries = Data.index.nunique()

print("Number of unique countries:", num_unique_countries)
# Out:
# Number of unique countries: 187

# %% [markdown]
# 8. Check if there are any duplicate country entries and remove them if
# needed.

# %%
duplicate_countries = Data.index[Data.index.duplicated(keep=False)]

if len(duplicate_countries) > 0:
    print("Duplicate countries found:\n", duplicate_countries)
    Data = Data[~Data.index.duplicated(keep='first')] 
    print("Duplicate countries removed.")
else:
    print("No duplicate countries found.")

Data.head()
# Out:
# No duplicate countries found.
#       Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 0        Afghanistan      36263   1269      25198    9796      106.0
# 1            Albania       4880    144       2745    1991      117.0
# 2            Algeria      27973   1163      18837    7973      616.0
# 3            Andorra        907     52        803      52       10.0
# 4             Angola        950     41        242     667       18.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
# ...

# %%
Data
# Out:
#            Country/Region  Confirmed Deaths  Recovered  Active  New_cases  \
# index
# 0             Afghanistan      36263   1269      25198    9796      106.0
# 1                 Albania       4880    144       2745    1991      117.0
# 2                 Algeria      27973   1163      18837    7973      616.0
# 3                 Andorra        907     52        803      52       10.0
# 4                  Angola        950     41        242     667       18.0
# ...                   ...        ...    ...        ...     ...        ...
# 182    West Bank and Gaza      10621     78       3752    6791      152.0
# 183        Western Sahara         10      1          8       1        0.0
# 184                 Yemen       1691    483        833     375       10.0
# 185                Zambia       4552    140       2815    1597       71.0
# 186              Zimbabwe       2704    non        542    2126      192.0
#
# ...

# %% [markdown]
# 9. Find the mean, median, and standard deviation of total cases.

# %% [markdown]
# 10. Find out the string in Deaths Column and replace it with the
# mean of Deaths column.

# %%
import pandas as pd
import numpy as np


Data['Deaths'] = pd.to_numeric(Data['Deaths'], errors='coerce')

mean_deaths = Data['Deaths'].mean()

Data['Deaths'] = Data['Deaths'].fillna(mean_deaths)

print(Data.head())
# Out:
#       Country/Region  Confirmed  Deaths  Recovered  Active  New_cases  \
# index
# 0        Afghanistan      36263  1269.0      25198    9796      106.0
# 1            Albania       4880   144.0       2745    1991      117.0
# 2            Algeria      27973  1163.0      18837    7973      616.0
# 3            Andorra        907    52.0        803      52       10.0
# 4             Angola        950    41.0        242     667       18.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# ...

# %% [markdown]
# 11. Change the datatype of column Deaths

# %%
Data['Deaths'] = Data['Deaths'].astype(int)

print(Data.head())
print(Data.dtypes)
# Out:
#       Country/Region  Confirmed  Deaths  Recovered  Active  New_cases  \
# index
# 0        Afghanistan      36263    1269      25198    9796      106.0
# 1            Albania       4880     144       2745    1991      117.0
# 2            Algeria      27973    1163      18837    7973      616.0
# 3            Andorra        907      52        803      52       10.0
# 4             Angola        950      41        242     667       18.0
#
#        New_deaths  New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0            10.0             18                3.50                  69.49
# 1             6.0             63                2.95                  56.25
# 2             8.0            749                4.16                  67.34
# 3             0.0              0                5.73                  88.53
# 4             1.0              0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# ...

# %% [markdown]
# 12. Calculate total number of Death and Recovery all over the
# world

# %%
total_deaths = Data['Deaths'].sum()
total_recoveries = Data['Recovered'].sum()

print("Total Deaths Worldwide:", total_deaths)
print("Total Recoveries Worldwide:", total_recoveries)
# Out:
# Total Deaths Worldwide: 657516
# Total Recoveries Worldwide: 9468087

# %% [markdown]
# 13. How many countries have more than 1 million total cases

# %% [markdown]
# 14. Which countries have a recovery rate (Recovered / Total Cases)
# above 95%

# %% [markdown]
# 15. Drop columns name WHO Region and Confirmed

# %%
Data = Data.drop(['WHO_Region', 'Confirmed'], axis=1)


print(Data.head())
# Out:
#       Country/Region  Deaths  Recovered  Active  New_cases  New_deaths  \
# index
# 0        Afghanistan    1269      25198    9796      106.0        10.0
# 1            Albania     144       2745    1991      117.0         6.0
# 2            Algeria    1163      18837    7973      616.0         8.0
# 3            Andorra      52        803      52       10.0         0.0
# 4             Angola      41        242     667       18.0         1.0
#
#        New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0                 18                3.50                  69.49
# 1                 63                2.95                  56.25
# 2                749                4.16                  67.34
# 3                  0                5.73                  88.53
# 4                  0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %% [markdown]
# 16. Find the Country with the Max Deaths

# %%
country_with_max_deaths = Data.loc[Data['Deaths'].idxmax()].name

print("Country with maximum deaths:", country_with_max_deaths)
# Out:
# Country with maximum deaths: 173

# %% [markdown]
# 17. Sort Countries by Deaths (Descending Order)

# %%
sorted_data = Data.sort_values(by=['Deaths'], ascending=False)

print(sorted_data[['Deaths']])
# Out:
#        Deaths
# index
# 173    148011
# 23      87618
# 177     45844
# 111     44022
# 85      35112
# ...       ...
# 141         0
# 130         0
# 142         0
# 168         0
# 181         0
#
# [187 rows x 1 columns]

# %% [markdown]
# 18. Make new column name Total_cases that have a sum of Deaths,
# Recovered , Active

# %%
Data['Total_cases'] = Data['Deaths'] + Data['Recovered'] + Data['Active']

print(Data.head())
# Out:
#       Country/Region  Deaths  Recovered  Active  New_cases  New_deaths  \
# index
# 0        Afghanistan    1269      25198    9796      106.0        10.0
# 1            Albania     144       2745    1991      117.0         6.0
# 2            Algeria    1163      18837    7973      616.0         8.0
# 3            Andorra      52        803      52       10.0         0.0
# 4             Angola      41        242     667       18.0         1.0
#
#        New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0                 18                3.50                  69.49
# 1                 63                2.95                  56.25
# 2                749                4.16                  67.34
# 3                  0                5.73                  88.53
# 4                  0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %% [markdown]
# 19. Calculate Death_Rate for Each Country (Deaths per Total
# Cases) by suing formula (Desths/Total_cases)*100 and save it in
# Dath_Rate column

# %%
Data['Death_Rate'] = (Data['Deaths'] / Data['Total_cases']) * 100

print(Data.head())
# Out:
#       Country/Region  Deaths  Recovered  Active  New_cases  New_deaths  \
# index
# 0        Afghanistan    1269      25198    9796      106.0        10.0
# 1            Albania     144       2745    1991      117.0         6.0
# 2            Algeria    1163      18837    7973      616.0         8.0
# 3            Andorra      52        803      52       10.0         0.0
# 4             Angola      41        242     667       18.0         1.0
#
#        New_recovered  Deaths_/_100_Cases  Recovered_/_100_Cases  \
# index
# 0                 18                3.50                  69.49
# 1                 63                2.95                  56.25
# 2                749                4.16                  67.34
# 3                  0                5.73                  88.53
# 4                  0                4.32                  25.47
#
#        Deaths_/_100_Recovered  Confirmed_last_week  1_week_change  \
# index
# ...

# %% [markdown]
# 20. Identify countries where total cases are increasing but death
# rates remain low.

# %%
data = {
    'Country': ['CountryA', 'CountryB', 'CountryC', 'CountryA', 'CountryB', 'CountryC'],
    'Date': ['2023-12-20', '2023-12-20', '2023-12-20', '2023-12-27', '2023-12-27', '2023-12-27'],
    'Total_Cases': [1000, 500, 200, 1200, 520, 210],
    'Deaths': [10, 5, 2, 12, 5, 2]
}
df = pd.DataFrame(data)

df['Case_Change'] = df.groupby('Country')['Total_Cases'].diff()
df['Death_Rate'] = (df['Deaths'] / df['Total_Cases']) * 100
df['Death_Rate_Change'] = df.groupby('Country')['Death_Rate'].diff()

increasing_cases_low_deaths = df[
    (df['Case_Change'] > df['Total_Cases'].shift() * 0.1) & 
    (df['Death_Rate'] < 2)
]

countries = increasing_cases_low_deaths['Country'].unique()

print("Countries with increasing cases and low death rates:")
print(countries)
# Out:
# Countries with increasing cases and low death rates:
# ['CountryA']

# %% [markdown]
# 21. print head of only 2 columns Country/Region  and Death_Rate

# %%
print(Data[['Country/Region', 'Death_Rate']].head())
# Out:
#       Country/Region  Death_Rate
# index
# 0        Afghanistan    3.499435
# 1            Albania    2.950820
# 2            Algeria    4.157581
# 3            Andorra    5.733186
# 4             Angola    4.315789

# %% [markdown]
# 22. Create a scatter plot comparing total cases and total deaths.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(Data['Total_cases'], Data['Deaths'], alpha=0.5)
plt.xlabel("Total Cases")
plt.ylabel("Total Deaths")
plt.title("Scatter Plot of Total Cases vs. Total Deaths")
plt.grid(True)
plt.show()

# %% [markdown]
# 23. Save dataset in CSV format.

# %%
Data.to_csv('covid_data_processed.csv', index=True)
